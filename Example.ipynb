# %%
import uuid
import pandas as pd

from qshed.client import QShedClient
from qshed.client.models.data import Entity, Collection, CollectionDatabase

# %%
client = QShedClient("http://localhost:4000")

# %%
client.entity.get_roots()
# Out:
# []

# %%
entity = Entity(
    name="Example entity",
    data_="x"*10000,
    type=0
)

# %%
e = client.entity.delete(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 e = client.entity.delete(1)
#
# AttributeError: 'EntityModule' object has no attribute 'delete'

# %%
client.entity.get_roots()
# Out:
# [Entity(id=1, name='Example entity', display_name=None, data_='...', type=1, parent=None, children=[], timeseries=None, collections=[]),
#  Entity(id=2, name='Example entity', display_name=None, data_='...', type=0, parent=None, children=[], timeseries=None, collections=[]),
#  Entity(id=3, name='Example entity', display_name=None, data_='...', type=0, parent=None, children=[], timeseries=None, collections=[])]

# %%
s = "abc"

# %%
bytes(s, "utf-8")
# Out:
# b'abc'
